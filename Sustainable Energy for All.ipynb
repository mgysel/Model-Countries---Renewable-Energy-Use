# %% [markdown]
# # Sustainable Energy for All
#
# ## Introduction
#
# The World Bank's Sustainable Energy For All (SE4All) Database provides country level historical data for access to electricity and non-solid fuel, share of renewable energy in total final energy consumption by technology, and energy intensity rate of improvement.
#
# The SE4All database can be found at
# http://databank.worldbank.org/data/reports.aspx?source=sustainable-energy-for-all&Type=TABLE&preview=on#

# %% [markdown]
# ## Gather
#
# The SE4All database was manually downloaded.

# %%
# Load dependencies
import numpy as np
import pandas as pd

# %%
# Import data
data_df = pd.read_csv('data/data.csv')
def_df = pd.read_csv('data/definition.csv')

# %%
# Check def_df
def_df
# Out:
#                              Code  \
# 0    1.2_ACCESS.ELECTRICITY.RURAL
# 1      1.1_ACCESS.ELECTRICITY.TOT
# 2    1.3_ACCESS.ELECTRICITY.URBAN
# 3    6.1_PRIMARY.ENERGY.INTENSITY
# 4    4.1.2_REN.ELECTRICITY.OUTPUT
# 5     4.1_SHARE.RE.IN.ELECTRICITY
# 6              3.1_RE.CONSUMPTION
# 7      2.1_SHARE.TOTAL.RE.IN.TFEC
# 8  4.1.1_TOTAL.ELECTRICITY.OUTPUT
# 9   1.1_TOTAL.FINAL.ENERGY.CONSUM
#
#                                       Indicator Name  \
# 0  Access to electricity (% of rural population w...
# 1      Access to electricity (% of total population)
# 2  Access to electricity (% of urban population w...
# 3  Energy intensity level of primary energy (MJ/2...
# 4                 Renewable electricity output (GWh)
# 5  Renewable electricity share of total electrici...
# 6                  Renewable energy consumption (TJ)
# 7                 Renewable energy share of TFEC (%)
# 8                     Total electricity output (GWh)
# 9         Total final energy consumption (TFEC) (TJ)
#
#                                      Long definition
# 0  Access to electricity (% of rural population w...
# 1  Access to electricity (% of total population):...
# 2  Access to electricity (% of urban population w...
# 3  Energy intensity level of primary energy (MJ/2...
# 4  Renewable electricity output (GWh): Electric o...
# 5  Renewable electricity share of total electrici...
# 6  Renewable energy consumption (TJ): This indica...
# 7  Renewable energy share of TFEC (%): Share of r...
# 8  Total electricity output (GWh): Total number o...
# 9  Total final energy consumption (TFEC): This in...

# %%
# Check data
data_df.head()
# Out:
#   Country Name Country Code    Time Time Code  \
# 0  Afghanistan          AFG  1990.0    YR1990
# 1  Afghanistan          AFG  1991.0    YR1991
# 2  Afghanistan          AFG  1992.0    YR1992
# 3  Afghanistan          AFG  1993.0    YR1993
# 4  Afghanistan          AFG  1994.0    YR1994
#
#   Access to Clean Fuels and Technologies for cooking (% of total population) [2.1_ACCESS.CFT.TOT]  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Access to electricity (% of rural population with access) [1.2_ACCESS.ELECTRICITY.RURAL]  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Access to electricity (% of total population) [1.1_ACCESS.ELECTRICITY.TOT]  \
# 0                                0.00999999977648258
# 1                                0.00999999977648258
# 2                                0.00999999977648258
# 3                                0.00999999977648258
# 4                                0.00999999977648258
#
#   Access to electricity (% of urban population with access) [1.3_ACCESS.ELECTRICITY.URBAN]  \
# 0                                   52.0369758605957
# 1                                   53.8098373413086
# 2                                   55.5825233459473
# 3                                   57.3541793823242
# 4                                   59.1237754821777
#
#   Energy intensity level of primary energy (MJ/2011 USD PPP) [6.1_PRIMARY.ENERGY.INTENSITY]  \
# 0                                   1.88411277331996
# 1                                   1.99591306318908
# 2                                   1.33250174740999
# 3                                   1.76063654184963
# 4                                   2.24561299646338
#
#   Renewable electricity output (GWh) [4.1.2_REN.ELECTRICITY.OUTPUT]  \
# 0                                                764
# 1                                                690
# 2                                                478
# 3                                                475
# 4                                                472
#
#   Renewable electricity share of total electricity output (%) [4.1_SHARE.RE.IN.ELECTRICITY]  \
# 0                                              67.73
# 1                                              67.98
# 2                                              67.99
# 3                                              68.35
# 4                                               68.7
#
#   Renewable energy consumption (TJ) [3.1_RE.CONSUMPTION]  \
# 0                                           6312.392
# 1                                           6361.651
# 2                                           6546.363
# 3                                           7849.649
# 4                                           8305.308
#
#   Renewable energy share of TFEC (%) [2.1_SHARE.TOTAL.RE.IN.TFEC]  \
# 0                                   15.9245316828932
# 1                                   17.0364435282942
# 2                                   26.5216286544368
# 3                                   30.5856670489932
# 4                                   32.7962505504008
#
#   Total electricity output (GWh) [4.1.1_TOTAL.ELECTRICITY.OUTPUT]  \
# 0                                               1128
# 1                                               1015
# 2                                                703
# 3                                                695
# 4                                                687
#
#   Total final energy consumption (TFEC) (TJ) [1.1_TOTAL.FINAL.ENERGY.CONSUM]
# 0                                        39639.42002
# 1                                       37341.426275
# 2                                        24683.11085
# 3                                       25664.468875
# 4                                        25323.95582

# %% [markdown]
# ## Assess
# ### Summary of Data Issues
# #### Quality
# - Time/Time Code show the same information
# - Column names very long
# - Null Values might not be of null type
# - The last 5 rows do not appear to be records
# - Time of type float
# - All other columns of type object
# - Null values, most likely due to the last 5 rows not being observations
# - Round percentages to 2 decimal points
# - Percentages rounded to different digits
# - Make sure no impossible percentages (<0 or >1)
# - There are several instances of very specific values for columns 4, 5, 6, 7, 11, 12, 14. Are these correct?
#
# #### Tidiness
# - None
#
# ##### Visual Assessment

# %%
data_df.head()
# Out:
#   Country Name Country Code    Time Time Code  \
# 0  Afghanistan          AFG  1990.0    YR1990
# 1  Afghanistan          AFG  1991.0    YR1991
# 2  Afghanistan          AFG  1992.0    YR1992
# 3  Afghanistan          AFG  1993.0    YR1993
# 4  Afghanistan          AFG  1994.0    YR1994
#
#   Access to Clean Fuels and Technologies for cooking (% of total population) [2.1_ACCESS.CFT.TOT]  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Access to electricity (% of rural population with access) [1.2_ACCESS.ELECTRICITY.RURAL]  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Access to electricity (% of total population) [1.1_ACCESS.ELECTRICITY.TOT]  \
# 0                                0.00999999977648258
# 1                                0.00999999977648258
# 2                                0.00999999977648258
# 3                                0.00999999977648258
# 4                                0.00999999977648258
#
#   Access to electricity (% of urban population with access) [1.3_ACCESS.ELECTRICITY.URBAN]  \
# 0                                   52.0369758605957
# 1                                   53.8098373413086
# 2                                   55.5825233459473
# 3                                   57.3541793823242
# 4                                   59.1237754821777
#
#   Energy intensity level of primary energy (MJ/2011 USD PPP) [6.1_PRIMARY.ENERGY.INTENSITY]  \
# 0                                   1.88411277331996
# 1                                   1.99591306318908
# 2                                   1.33250174740999
# 3                                   1.76063654184963
# 4                                   2.24561299646338
#
#   Renewable electricity output (GWh) [4.1.2_REN.ELECTRICITY.OUTPUT]  \
# 0                                                764
# 1                                                690
# 2                                                478
# 3                                                475
# 4                                                472
#
#   Renewable electricity share of total electricity output (%) [4.1_SHARE.RE.IN.ELECTRICITY]  \
# 0                                              67.73
# 1                                              67.98
# 2                                              67.99
# 3                                              68.35
# 4                                               68.7
#
#   Renewable energy consumption (TJ) [3.1_RE.CONSUMPTION]  \
# 0                                           6312.392
# 1                                           6361.651
# 2                                           6546.363
# 3                                           7849.649
# 4                                           8305.308
#
#   Renewable energy share of TFEC (%) [2.1_SHARE.TOTAL.RE.IN.TFEC]  \
# 0                                   15.9245316828932
# 1                                   17.0364435282942
# 2                                   26.5216286544368
# 3                                   30.5856670489932
# 4                                   32.7962505504008
#
#   Total electricity output (GWh) [4.1.1_TOTAL.ELECTRICITY.OUTPUT]  \
# 0                                               1128
# 1                                               1015
# 2                                                703
# 3                                                695
# 4                                                687
#
#   Total final energy consumption (TFEC) (TJ) [1.1_TOTAL.FINAL.ENERGY.CONSUM]
# 0                                        39639.42002
# 1                                       37341.426275
# 2                                        24683.11085
# 3                                       25664.468875
# 4                                        25323.95582

# %% [markdown]
# From the above visual assessment, the following issues were determined:
# - Time/Time Code show the same information
# - Column names very long
# - Null Values might not be of null type
# - The last 5 rows do not appear to be records
#
# ##### Programmatic Assessment

# %%
# Check data types/null values
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6998 entries, 0 to 6997
# Data columns (total 15 columns):
# Country Name                                                                                       6995 non-null object
# Country Code                                                                                       6993 non-null object
# Time                                                                                               6993 non-null float64
# Time Code                                                                                          6993 non-null object
# Access to Clean Fuels and Technologies for cooking (% of total population) [2.1_ACCESS.CFT.TOT]    6993 non-null object
# Access to electricity (% of rural population with access) [1.2_ACCESS.ELECTRICITY.RURAL]           6993 non-null object
# Access to electricity (% of total population) [1.1_ACCESS.ELECTRICITY.TOT]                         6993 non-null object
# Access to electricity (% of urban population with access) [1.3_ACCESS.ELECTRICITY.URBAN]           6993 non-null object
# Energy intensity level of primary energy (MJ/2011 USD PPP) [6.1_PRIMARY.ENERGY.INTENSITY]          6993 non-null object
# Renewable electricity output (GWh) [4.1.2_REN.ELECTRICITY.OUTPUT]                                  6993 non-null object
# Renewable electricity share of total electricity output (%) [4.1_SHARE.RE.IN.ELECTRICITY]          6993 non-null object
# Renewable energy consumption (TJ) [3.1_RE.CONSUMPTION]                                             6993 non-null object
# Renewable energy share of TFEC (%) [2.1_SHARE.TOTAL.RE.IN.TFEC]                                    6993 non-null object
# Total electricity output (GWh) [4.1.1_TOTAL.ELECTRICITY.OUTPUT]                                    6993 non-null object
# Total final energy consumption (TFEC) (TJ) [1.1_TOTAL.FINAL.ENERGY.CONSUM]                         6993 non-null object
# dtypes: float64(1), object(14)
# memory usage: 820.2+ KB

# %% [markdown]
# The following issues were determined from checking info:
# - Time of type float
# - All other columns of type object
# - Null values, most likely due to the last 5 rows not being observations

# %%
# Check for duplicates
data_df.duplicated().sum()
# Out:
# 2

# %% [markdown]
# 2 rows are duplicates, most likely from the last 5 rows that are not observations

# %%
data_df.head()
# Out:
#   Country Name Country Code    Time Time Code  \
# 0  Afghanistan          AFG  1990.0    YR1990
# 1  Afghanistan          AFG  1991.0    YR1991
# 2  Afghanistan          AFG  1992.0    YR1992
# 3  Afghanistan          AFG  1993.0    YR1993
# 4  Afghanistan          AFG  1994.0    YR1994
#
#   Access to Clean Fuels and Technologies for cooking (% of total population) [2.1_ACCESS.CFT.TOT]  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Access to electricity (% of rural population with access) [1.2_ACCESS.ELECTRICITY.RURAL]  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Access to electricity (% of total population) [1.1_ACCESS.ELECTRICITY.TOT]  \
# 0                                0.00999999977648258
# 1                                0.00999999977648258
# 2                                0.00999999977648258
# 3                                0.00999999977648258
# 4                                0.00999999977648258
#
#   Access to electricity (% of urban population with access) [1.3_ACCESS.ELECTRICITY.URBAN]  \
# 0                                   52.0369758605957
# 1                                   53.8098373413086
# 2                                   55.5825233459473
# 3                                   57.3541793823242
# 4                                   59.1237754821777
#
#   Energy intensity level of primary energy (MJ/2011 USD PPP) [6.1_PRIMARY.ENERGY.INTENSITY]  \
# 0                                   1.88411277331996
# 1                                   1.99591306318908
# 2                                   1.33250174740999
# 3                                   1.76063654184963
# 4                                   2.24561299646338
#
#   Renewable electricity output (GWh) [4.1.2_REN.ELECTRICITY.OUTPUT]  \
# 0                                                764
# 1                                                690
# 2                                                478
# 3                                                475
# 4                                                472
#
#   Renewable electricity share of total electricity output (%) [4.1_SHARE.RE.IN.ELECTRICITY]  \
# 0                                              67.73
# 1                                              67.98
# 2                                              67.99
# 3                                              68.35
# 4                                               68.7
#
#   Renewable energy consumption (TJ) [3.1_RE.CONSUMPTION]  \
# 0                                           6312.392
# 1                                           6361.651
# 2                                           6546.363
# 3                                           7849.649
# 4                                           8305.308
#
#   Renewable energy share of TFEC (%) [2.1_SHARE.TOTAL.RE.IN.TFEC]  \
# 0                                   15.9245316828932
# 1                                   17.0364435282942
# 2                                   26.5216286544368
# 3                                   30.5856670489932
# 4                                   32.7962505504008
#
#   Total electricity output (GWh) [4.1.1_TOTAL.ELECTRICITY.OUTPUT]  \
# 0                                               1128
# 1                                               1015
# 2                                                703
# 3                                                695
# 4                                                687
#
#   Total final energy consumption (TFEC) (TJ) [1.1_TOTAL.FINAL.ENERGY.CONSUM]
# 0                                        39639.42002
# 1                                       37341.426275
# 2                                        24683.11085
# 3                                       25664.468875
# 4                                        25323.95582

# %%
# Check the value counts for each column
data_df.iloc[:,14].value_counts()
# Out:
# ..                983
# 0                 261
# 362.5               3
# 422.4               3
# 447.044225          3
# 54.78076            3
# 405.5               3
# 464.2               3
# 3096                3
# 466.7               2
# 1188.28             2
# 2597.5              2
# 278.5               2
# 72.2414             2
# 59.21076            2
# 1110.4              2
# 496.588525          2
# 1145.52             2
# 6670.695            2
# 21245.49            2
# 1201.55             2
# 463.1               2
# 323.6               2
# 466.08              2
# 3132                2
# 369.5               2
# 2169.9              2
# 2287.9              2
# 1117.44             2
# 1884.2465           1
#                  ...
# 4851580.857624      1
# 4456.95             1
# 97051.8792746       1
# 1460677.302504      1
# 7682.48743          1
# 2243913.115392      1
# 2799835.707636      1
# 5454.067255         1
# 1753.651799685      1
# 260192.537856       1
# 136095.618384       1
# 29416.31755         1
# 23961.881649        1
# 8671255.270632      1
# 18465.40975         1
# 5021.94             1
# 82698.92964         1
# 1118140.456968      1
# 1999290.240036      1
# 4974.3755           1
# 146503.375164       1
# 203005.58094        1
# 19888.3794          1
# 188225.088372       1
# 5440.895465         1
# 537103.805472       1
# 761939.61282        1
# 53531.043156        1
# 497028.760704       1
# 3068.555155         1
# Name: Total final energy consumption (TFEC) (TJ) [1.1_TOTAL.FINAL.ENERGY.CONSUM], Length: 5717, dtype: int64

# %% [markdown]
# The following issues were determined from checking value_counts:
# - Percentages rounded to different digits
# - There are several instances of very specific values for columns 4, 5, 6, 7, 11, 12, 14. Are these correct?

# %% [markdown]
# ## Clean
# ### Summary of Data Issues
# #### Quality
# - Delete Time Code Column
# - Reduce column name lengths
# - Change null values ('..') to null values
# - Delete the last 5 rows if they do not hold relevant information
# - Check any null values
# - Change time column from object to date datatype
# - Change percent columns from object to float datatype
# - Round percentages to 2 decimal points
# - Make sure no impossible percentages (<0 or >1)
# - Make sure duplicate values are correct, especially for columns (in data_df) 4, 5, 6, 7, 11, 12, 14. Are these correct?
#
# #### Tidiness
# - None

# %%
# Make copy of data_df
data_df_clean = data_df.copy()

# %% [markdown]
# ### Delete Country Code and Time Code Columns
#
# #### Define
# Drop 'Time Code' column from data_df_clean
#
# #### Code

# %%
# Drop columns
data_df_clean.drop(axis=1, columns=['Time Code'], inplace=True)

# %% [markdown]
# #### Test

# %%
# Check column names
data_df_clean.head()
# Out:
#   Country Name Country Code    Time  \
# 0  Afghanistan          AFG  1990.0
# 1  Afghanistan          AFG  1991.0
# 2  Afghanistan          AFG  1992.0
# 3  Afghanistan          AFG  1993.0
# 4  Afghanistan          AFG  1994.0
#
#   Access to Clean Fuels and Technologies for cooking (% of total population) [2.1_ACCESS.CFT.TOT]  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Access to electricity (% of rural population with access) [1.2_ACCESS.ELECTRICITY.RURAL]  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Access to electricity (% of total population) [1.1_ACCESS.ELECTRICITY.TOT]  \
# 0                                0.00999999977648258
# 1                                0.00999999977648258
# 2                                0.00999999977648258
# 3                                0.00999999977648258
# 4                                0.00999999977648258
#
#   Access to electricity (% of urban population with access) [1.3_ACCESS.ELECTRICITY.URBAN]  \
# 0                                   52.0369758605957
# 1                                   53.8098373413086
# 2                                   55.5825233459473
# 3                                   57.3541793823242
# 4                                   59.1237754821777
#
#   Energy intensity level of primary energy (MJ/2011 USD PPP) [6.1_PRIMARY.ENERGY.INTENSITY]  \
# 0                                   1.88411277331996
# 1                                   1.99591306318908
# 2                                   1.33250174740999
# 3                                   1.76063654184963
# 4                                   2.24561299646338
#
#   Renewable electricity output (GWh) [4.1.2_REN.ELECTRICITY.OUTPUT]  \
# 0                                                764
# 1                                                690
# 2                                                478
# 3                                                475
# 4                                                472
#
#   Renewable electricity share of total electricity output (%) [4.1_SHARE.RE.IN.ELECTRICITY]  \
# 0                                              67.73
# 1                                              67.98
# 2                                              67.99
# 3                                              68.35
# 4                                               68.7
#
#   Renewable energy consumption (TJ) [3.1_RE.CONSUMPTION]  \
# 0                                           6312.392
# 1                                           6361.651
# 2                                           6546.363
# 3                                           7849.649
# 4                                           8305.308
#
#   Renewable energy share of TFEC (%) [2.1_SHARE.TOTAL.RE.IN.TFEC]  \
# 0                                   15.9245316828932
# 1                                   17.0364435282942
# 2                                   26.5216286544368
# 3                                   30.5856670489932
# 4                                   32.7962505504008
#
#   Total electricity output (GWh) [4.1.1_TOTAL.ELECTRICITY.OUTPUT]  \
# 0                                               1128
# 1                                               1015
# 2                                                703
# 3                                                695
# 4                                                687
#
#   Total final energy consumption (TFEC) (TJ) [1.1_TOTAL.FINAL.ENERGY.CONSUM]
# 0                                        39639.42002
# 1                                       37341.426275
# 2                                        24683.11085
# 3                                       25664.468875
# 4                                        25323.95582

# %% [markdown]
# ### Reduce Column Name Lengths
#
# #### Define
# Because this is just going to be used in Tableau, remove the descriptors in brackets. The names do not need to be lowercase without spaces.
#
# #### Code

# %%
# Rename columns
# Loop through each name
for name in data_df_clean.columns[2:]:
    # Take initial portion of name, lowercase, replace spaces with underscores
    new_name = name.split('[')[0].strip()
    # Replace name in data_df_clean
    data_df_clean.rename(columns={name: new_name}, index=str, inplace=True)

# Change Time column to Year
data_df_clean.rename(columns={'Time': 'Year'}, index=str, inplace=True)

# %% [markdown]
# #### Test

# %%
data_df_clean.head()
# Out:
#   Country Name Country Code    Year  \
# 0  Afghanistan          AFG  1990.0
# 1  Afghanistan          AFG  1991.0
# 2  Afghanistan          AFG  1992.0
# 3  Afghanistan          AFG  1993.0
# 4  Afghanistan          AFG  1994.0
#
#   Access to Clean Fuels and Technologies for cooking (% of total population)  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Access to electricity (% of rural population with access)  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Access to electricity (% of total population)  \
# 0                           0.00999999977648258
# 1                           0.00999999977648258
# 2                           0.00999999977648258
# 3                           0.00999999977648258
# 4                           0.00999999977648258
#
#   Access to electricity (% of urban population with access)  \
# 0                                   52.0369758605957
# 1                                   53.8098373413086
# 2                                   55.5825233459473
# 3                                   57.3541793823242
# 4                                   59.1237754821777
#
#   Energy intensity level of primary energy (MJ/2011 USD PPP)  \
# 0                                   1.88411277331996
# 1                                   1.99591306318908
# 2                                   1.33250174740999
# 3                                   1.76063654184963
# 4                                   2.24561299646338
#
#   Renewable electricity output (GWh)  \
# 0                                764
# 1                                690
# 2                                478
# 3                                475
# 4                                472
#
#   Renewable electricity share of total electricity output (%)  \
# 0                                              67.73
# 1                                              67.98
# 2                                              67.99
# 3                                              68.35
# 4                                               68.7
#
#   Renewable energy consumption (TJ) Renewable energy share of TFEC (%)  \
# 0                          6312.392                   15.9245316828932
# 1                          6361.651                   17.0364435282942
# 2                          6546.363                   26.5216286544368
# 3                          7849.649                   30.5856670489932
# 4                          8305.308                   32.7962505504008
#
#   Total electricity output (GWh) Total final energy consumption (TFEC) (TJ)
# 0                           1128                                39639.42002
# 1                           1015                               37341.426275
# 2                            703                                24683.11085
# 3                            695                               25664.468875
# 4                            687                                25323.95582

# %% [markdown]
# The column names are very long, but I think this is the best way to describe what the column/units are.

# %% [markdown]
# ### Change null values to nan
# #### Define
#
# - Change null values ('..') to null values
#
# #### Code

# %%
# Replace '..' values with nan
data_df_clean.replace('..',np.nan, inplace=True)

# %%
data_df_clean.head()
# Out:
#   Country Name Country Code    Year  \
# 0  Afghanistan          AFG  1990.0
# 1  Afghanistan          AFG  1991.0
# 2  Afghanistan          AFG  1992.0
# 3  Afghanistan          AFG  1993.0
# 4  Afghanistan          AFG  1994.0
#
#   Access to Clean Fuels and Technologies for cooking (% of total population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Access to electricity (% of rural population with access)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Access to electricity (% of total population)  \
# 0                           0.00999999977648258
# 1                           0.00999999977648258
# 2                           0.00999999977648258
# 3                           0.00999999977648258
# 4                           0.00999999977648258
#
#   Access to electricity (% of urban population with access)  \
# 0                                   52.0369758605957
# 1                                   53.8098373413086
# 2                                   55.5825233459473
# 3                                   57.3541793823242
# 4                                   59.1237754821777
#
#   Energy intensity level of primary energy (MJ/2011 USD PPP)  \
# 0                                   1.88411277331996
# 1                                   1.99591306318908
# 2                                   1.33250174740999
# 3                                   1.76063654184963
# 4                                   2.24561299646338
#
#   Renewable electricity output (GWh)  \
# 0                                764
# 1                                690
# 2                                478
# 3                                475
# 4                                472
#
#   Renewable electricity share of total electricity output (%)  \
# 0                                              67.73
# 1                                              67.98
# 2                                              67.99
# 3                                              68.35
# 4                                               68.7
#
#   Renewable energy consumption (TJ) Renewable energy share of TFEC (%)  \
# 0                          6312.392                   15.9245316828932
# 1                          6361.651                   17.0364435282942
# 2                          6546.363                   26.5216286544368
# 3                          7849.649                   30.5856670489932
# 4                          8305.308                   32.7962505504008
#
#   Total electricity output (GWh) Total final energy consumption (TFEC) (TJ)
# 0                           1128                                39639.42002
# 1                           1015                               37341.426275
# 2                            703                                24683.11085
# 3                            695                               25664.468875
# 4                            687                                25323.95582

# %% [markdown]
# #### Test

# %%
# Check value counts and null values of different columns
data_df_clean.iloc[:,12].value_counts()
data_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6998 entries, 0 to 6997
# Data columns (total 14 columns):
# Country Name                                                                  6995 non-null object
# Country Code                                                                  6993 non-null object
# Year                                                                          6993 non-null float64
# Access to Clean Fuels and Technologies for cooking (% of total population)    3230 non-null object
# Access to electricity (% of rural population with access)                     5129 non-null object
# Access to electricity (% of total population)                                 5770 non-null object
# Access to electricity (% of urban population with access)                     5771 non-null object
# Energy intensity level of primary energy (MJ/2011 USD PPP)                    4947 non-null object
# Renewable electricity output (GWh)                                            5514 non-null object
# Renewable electricity share of total electricity output (%)                   5512 non-null object
# Renewable energy consumption (TJ)                                             6010 non-null object
# Renewable energy share of TFEC (%)                                            5749 non-null object
# Total electricity output (GWh)                                                5514 non-null object
# Total final energy consumption (TFEC) (TJ)                                    6010 non-null object
# dtypes: float64(1), object(13)
# memory usage: 820.1+ KB

# %% [markdown]
# ### Drop Rows that aren't Records
#
# #### Define
# Drop last few rows that are not really records
#
# #### Code

# %%
# Delete rows 6993 to 6997
data_df_clean.drop(axis=0, index=['6993','6994','6995','6996','6997'], inplace=True)

# %% [markdown]
# #### Test

# %%
data_df_clean.tail()
# Out:
#      Country Name Country Code    Year  \
# 6988     Zimbabwe          ZWE  2012.0
# 6989     Zimbabwe          ZWE  2013.0
# 6990     Zimbabwe          ZWE  2014.0
# 6991     Zimbabwe          ZWE  2015.0
# 6992     Zimbabwe          ZWE  2016.0
#
#      Access to Clean Fuels and Technologies for cooking (% of total population)  \
# 6988                                              30.02
# 6989                                              29.88
# 6990                                              29.63
# 6991                                              29.36
# 6992                                              29.05
#
#      Access to electricity (% of rural population with access)  \
# 6988                                    12.981644179652
# 6989                                   13.6699177131116
# 6990                                                9.8
# 6991                                                9.7
# 6992                                    15.575583712267
#
#      Access to electricity (% of total population)  \
# 6988                              36.7288780212402
# 6989                              37.0768127441406
# 6990                                          32.3
# 6991                                          33.7
# 6992                              38.1451377868652
#
#      Access to electricity (% of urban population with access)  \
# 6988                                    85.306770324707
# 6989                                   85.3514785766602
# 6990                                               83.4
# 6991                                               81.2
# 6992                                   85.5001602172852
#
#      Energy intensity level of primary energy (MJ/2011 USD PPP)  \
# 6988                                   18.4372464925512
# 6989                                   18.1529665775605
# 6990                                   15.7495813871173
# 6991                                   15.8038970473848
# 6992                                                NaN
#
#      Renewable electricity output (GWh)  \
# 6988                               5558
# 6989                               5162
# 6990                               5575
# 6991                                NaN
# 6992                                NaN
#
#      Renewable electricity share of total electricity output (%)  \
# 6988                                              60.39
# 6989                                              53.94
# 6990                                              55.62
# 6991                                                NaN
# 6992                                                NaN
#
#      Renewable energy consumption (TJ) Renewable energy share of TFEC (%)  \
# 6988                          304744.9                   78.0197020630944
# 6989                          311169.4                   79.5610938290255
# 6990                          320293.3                   81.0492915007339
# 6991                          324422.6                    81.797808552401
# 6992                               NaN                                NaN
#
#      Total electricity output (GWh) Total final energy consumption (TFEC) (TJ)
# 6988                           9203                              390599.927892
# 6989                           9570                              391107.493656
# 6990                          10023                              395183.343456
# 6991                            NaN                              396615.270924
# 6992                            NaN                                        NaN

# %% [markdown]
# ### Check Null Values
#
# #### Define
# Check columns with null values
#
# #### Code

# %%
# Find columns with null values
data_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6993 entries, 0 to 6992
# Data columns (total 14 columns):
# Country Name                                                                  6993 non-null object
# Country Code                                                                  6993 non-null object
# Year                                                                          6993 non-null float64
# Access to Clean Fuels and Technologies for cooking (% of total population)    3230 non-null object
# Access to electricity (% of rural population with access)                     5129 non-null object
# Access to electricity (% of total population)                                 5770 non-null object
# Access to electricity (% of urban population with access)                     5771 non-null object
# Energy intensity level of primary energy (MJ/2011 USD PPP)                    4947 non-null object
# Renewable electricity output (GWh)                                            5514 non-null object
# Renewable electricity share of total electricity output (%)                   5512 non-null object
# Renewable energy consumption (TJ)                                             6010 non-null object
# Renewable energy share of TFEC (%)                                            5749 non-null object
# Total electricity output (GWh)                                                5514 non-null object
# Total final energy consumption (TFEC) (TJ)                                    6010 non-null object
# dtypes: float64(1), object(13)
# memory usage: 819.5+ KB

# %% [markdown]
# #### Test
#
# It looks like the columns with null values are just missing data. There is no way for me to determine the missing data, so I will just deal with these during the EDA.

# %% [markdown]
# ### Change Columns to Correct Datatypes
#
# #### Define
# Check datatypes and change to correct datatypes
#
# #### Code

# %%
data_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6993 entries, 0 to 6992
# Data columns (total 14 columns):
# Country Name                                                                  6993 non-null object
# Country Code                                                                  6993 non-null object
# Year                                                                          6993 non-null float64
# Access to Clean Fuels and Technologies for cooking (% of total population)    3230 non-null object
# Access to electricity (% of rural population with access)                     5129 non-null object
# Access to electricity (% of total population)                                 5770 non-null object
# Access to electricity (% of urban population with access)                     5771 non-null object
# Energy intensity level of primary energy (MJ/2011 USD PPP)                    4947 non-null object
# Renewable electricity output (GWh)                                            5514 non-null object
# Renewable electricity share of total electricity output (%)                   5512 non-null object
# Renewable energy consumption (TJ)                                             6010 non-null object
# Renewable energy share of TFEC (%)                                            5749 non-null object
# Total electricity output (GWh)                                                5514 non-null object
# Total final energy consumption (TFEC) (TJ)                                    6010 non-null object
# dtypes: float64(1), object(13)
# memory usage: 819.5+ KB

# %%
# Change index datatype to int
data_df_clean.index = data_df_clean.index.map(int)
# Change year datatype to int
data_df_clean.Year = data_df_clean.Year.astype(int)
# Change most columns to float
data_df_clean.iloc[:,3:] = data_df_clean.iloc[:,3:].astype(float)
# Round decimals to 2 places
data_df_clean = data_df_clean.round(2)

# %% [markdown]
# #### Test

# %%
data_df_clean.head()
# Out:
#   Country Name Country Code  Year  \
# 0  Afghanistan          AFG  1990
# 1  Afghanistan          AFG  1991
# 2  Afghanistan          AFG  1992
# 3  Afghanistan          AFG  1993
# 4  Afghanistan          AFG  1994
#
#    Access to Clean Fuels and Technologies for cooking (% of total population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Access to electricity (% of rural population with access)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Access to electricity (% of total population)  \
# 0                                           0.01
# 1                                           0.01
# 2                                           0.01
# 3                                           0.01
# 4                                           0.01
#
#    Access to electricity (% of urban population with access)  \
# 0                                              52.04
# 1                                              53.81
# 2                                              55.58
# 3                                              57.35
# 4                                              59.12
#
#    Energy intensity level of primary energy (MJ/2011 USD PPP)  \
# 0                                               1.88
# 1                                               2.00
# 2                                               1.33
# 3                                               1.76
# 4                                               2.25
#
#    Renewable electricity output (GWh)  \
# 0                               764.0
# 1                               690.0
# 2                               478.0
# 3                               475.0
# 4                               472.0
#
#    Renewable electricity share of total electricity output (%)  \
# 0                                              67.73
# 1                                              67.98
# 2                                              67.99
# 3                                              68.35
# 4                                              68.70
#
#    Renewable energy consumption (TJ)  Renewable energy share of TFEC (%)  \
# 0                            6312.39                               15.92
# 1                            6361.65                               17.04
# 2                            6546.36                               26.52
# 3                            7849.65                               30.59
# 4                            8305.31                               32.80
#
#    Total electricity output (GWh)  Total final energy consumption (TFEC) (TJ)
# 0                          1128.0                                    39639.42
# 1                          1015.0                                    37341.43
# 2                           703.0                                    24683.11
# 3                           695.0                                    25664.47
# 4                           687.0                                    25323.96

# %%
data_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6993 entries, 0 to 6992
# Data columns (total 14 columns):
# Country Name                                                                  6993 non-null object
# Country Code                                                                  6993 non-null object
# Year                                                                          6993 non-null int64
# Access to Clean Fuels and Technologies for cooking (% of total population)    3230 non-null float64
# Access to electricity (% of rural population with access)                     5129 non-null float64
# Access to electricity (% of total population)                                 5770 non-null float64
# Access to electricity (% of urban population with access)                     5771 non-null float64
# Energy intensity level of primary energy (MJ/2011 USD PPP)                    4947 non-null float64
# Renewable electricity output (GWh)                                            5514 non-null float64
# Renewable electricity share of total electricity output (%)                   5512 non-null float64
# Renewable energy consumption (TJ)                                             6010 non-null float64
# Renewable energy share of TFEC (%)                                            5749 non-null float64
# Total electricity output (GWh)                                                5514 non-null float64
# Total final energy consumption (TFEC) (TJ)                                    6010 non-null float64
# dtypes: float64(11), int64(1), object(2)
# memory usage: 819.5+ KB

# %% [markdown]
# All datatypes are now correct.

# %% [markdown]
# ### Make sure no impossible percentages
#
# #### Define
# Check min, max values for percentage columns
#
# #### Code

# %%
# Check if any percentage values > 100 or < 0
(data_df_clean.iloc[:,np.r_[2:6,8,10]] > 100).sum() + (data_df_clean.iloc[:,np.r_[2:6,8,10]] < 0).sum()
# Out:
# Year                                                                          6993
# Access to Clean Fuels and Technologies for cooking (% of total population)       0
# Access to electricity (% of rural population with access)                        0
# Access to electricity (% of total population)                                    0
# Renewable electricity output (GWh)                                            3365
# Renewable energy consumption (TJ)                                             4838
# dtype: int64

# %% [markdown]
# #### Test
#
# Per above, there are none.

# %% [markdown]
# ### Check Duplicates
#
# #### Define
# Check duplicate records and make sure they are correct
#
# #### Code

# %%
# Check duplciates
data_df_clean.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Test
# Per above, there are no duplicates

# %% [markdown]
# ## Export Data

# %%
# Export data
data_df_clean.to_csv('data/clean/energy.csv', index=False)

# %%
# Check that data was exported correctly
pd.read_csv('data/clean/energy.csv').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6993 entries, 0 to 6992
# Data columns (total 14 columns):
# Country Name                                                                  6993 non-null object
# Country Code                                                                  6993 non-null object
# Year                                                                          6993 non-null int64
# Access to Clean Fuels and Technologies for cooking (% of total population)    3230 non-null float64
# Access to electricity (% of rural population with access)                     5129 non-null float64
# Access to electricity (% of total population)                                 5770 non-null float64
# Access to electricity (% of urban population with access)                     5771 non-null float64
# Energy intensity level of primary energy (MJ/2011 USD PPP)                    4947 non-null float64
# Renewable electricity output (GWh)                                            5514 non-null float64
# Renewable electricity share of total electricity output (%)                   5512 non-null float64
# Renewable energy consumption (TJ)                                             6010 non-null float64
# Renewable energy share of TFEC (%)                                            5749 non-null float64
# Total electricity output (GWh)                                                5514 non-null float64
# Total final energy consumption (TFEC) (TJ)                                    6010 non-null float64
# dtypes: float64(11), int64(1), object(2)
# memory usage: 764.9+ KB

# %%
data_df_clean.query('Year == 1990').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 259 entries, 0 to 6966
# Data columns (total 14 columns):
# Country Name                                                                  259 non-null object
# Country Code                                                                  259 non-null object
# Year                                                                          259 non-null int64
# Access to Clean Fuels and Technologies for cooking (% of total population)    0 non-null float64
# Access to electricity (% of rural population with access)                     164 non-null float64
# Access to electricity (% of total population)                                 207 non-null float64
# Access to electricity (% of urban population with access)                     207 non-null float64
# Energy intensity level of primary energy (MJ/2011 USD PPP)                    184 non-null float64
# Renewable electricity output (GWh)                                            210 non-null float64
# Renewable electricity share of total electricity output (%)                   209 non-null float64
# Renewable energy consumption (TJ)                                             231 non-null float64
# Renewable energy share of TFEC (%)                                            210 non-null float64
# Total electricity output (GWh)                                                210 non-null float64
# Total final energy consumption (TFEC) (TJ)                                    231 non-null float64
# dtypes: float64(11), int64(1), object(2)
# memory usage: 30.4+ KB

# %%
data_df_clean
